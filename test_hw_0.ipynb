# %%
# %reload_ext autoreload
# %autoreload 2

from hw_0 import *

# %%
# List of experiment will run in this file
"""
python hw_0.py --exp 0 --hidden 16 --epochs 7000
python hw_0.py --exp 1 --hidden 16 --epochs 7000
python hw_0.py --exp 2 --hidden 16 --epochs 7000
python hw_0.py --exp 3 --hidden 16 --epochs 7000
python hw_0.py --exp 4 --hidden 16 --epochs 7000
python hw_0.py --exp 5 --hidden 16 --epochs 7000
python hw_0.py --exp 6 --hidden 16 --epochs 7000
python hw_0.py --exp 7 --hidden 16 --epochs 7000
python hw_0.py --exp 8 --hidden 16 --epochs 7000
python hw_0.py --exp 9 --hidden 16 --epochs 7000

"""
display_learning_curve_set('results','hw0_results')

# %%
# testing absolute error for each experiment
# training data set
fp = open("hw0_dataset.pkl", "rb")
foo = pickle.load(fp)
fp.close()
outs = foo.get('outs')
print(outs.shape)

# Test results pickle file
fp = open('results/hw0_resultsexp_07_hidden_16.pkl', "rb")
history = pickle.load(fp)
stored_args = pickle.load(fp)
pre = pickle.load(fp)

fp.close()
np.max(np.abs(pre-outs))
# Out:
# (256, 1)
# 1.999986708164215

# %%
# histogram plottin
display_histogram_absolute_error('results', 'hw0_results')
# Out:
# size of err is: 2560

# %%
arr = np.empty(0)

# %%
arr = np.append(arr, [1,2,3])

# %%
for i in arr:
    if i > 1:
        print (i)
# Out:
# 2.0
# 3.0
